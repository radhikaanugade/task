# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Load the dataset and print first 10 rows.

# %%
df = pd.read_csv('D:\\pandas\\bmw_car_data.csv')

# %%
df.head(10)
# Out:
#    ID Model_Name      Variant  Year Fuel_Type    Transmission  Engine_CC  \
# 0   1         X5       xDrive  2019  Electric          Manual       1496
# 1   2         X5  Luxury Line  2016  Electric       Automatic       1496
# 2   3         Z4      M Sport  2012  Electric  Semi-Automatic       4395
# 3   4         X7      M Sport  2013    Hybrid  Semi-Automatic       4395
# 4   5         X7       xDrive  2010  Electric          Manual       2993
# 5   6         X1      M Sport  2012    Petrol          Manual       2993
# 6   7         M3     Standard  2014    Hybrid  Semi-Automatic       4395
# 7   8       320d   Sport Line  2015  Electric  Semi-Automatic       1496
# 8   9         X3   Sport Line  2019  Electric          Manual       1998
# 9  10         i8  Luxury Line  2015    Petrol          Manual       1998
#
#    Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom      Owner_Type  \
# 0     395.18     492.04         20.48              68.33          Second
# ...

# %% [markdown]
# # Display shape,column names, and data types.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    100000 non-null  int64
#  1   Model_Name            100000 non-null  object
#  2   Variant               100000 non-null  object
#  3   Year                  100000 non-null  int64
#  4   Fuel_Type             100000 non-null  object
#  5   Transmission          100000 non-null  object
#  6   Engine_CC             100000 non-null  int64
#  7   Power_BHP             100000 non-null  float64
#  8   Torque_Nm             100000 non-null  float64
#  9   Mileage_kmpl          100000 non-null  float64
#  10  Price_Ex_Showroom     100000 non-null  float64
#  11  Owner_Type            100000 non-null  object
#  12  Insurance_Valid_Till  100000 non-null  int64
#  13  Location              100000 non-null  object
# ...

# %%
df.dtypes
# Out:
# ID                        int64
# Model_Name               object
# Variant                  object
# Year                      int64
# Fuel_Type                object
# Transmission             object
# Engine_CC                 int64
# Power_BHP               float64
# Torque_Nm               float64
# Mileage_kmpl            float64
# Price_Ex_Showroom       float64
# Owner_Type               object
# Insurance_Valid_Till      int64
# Location                 object
# Registration_State       object
# dtype: object

# %%
df.shape
# Out:
# (100000, 15)

# %%
df.columns
# Out:
# Index(['ID', 'Model_Name', 'Variant', 'Year', 'Fuel_Type', 'Transmission',
#        'Engine_CC', 'Power_BHP', 'Torque_Nm', 'Mileage_kmpl',
#        'Price_Ex_Showroom', 'Owner_Type', 'Insurance_Valid_Till', 'Location',
#        'Registration_State'],
#       dtype='object')

# %% [markdown]
# # Check for missing values and count per column.

# %%
df.isnull().sum()
# Out:
# ID                      0
# Model_Name              0
# Variant                 0
# Year                    0
# Fuel_Type               0
# Transmission            0
# Engine_CC               0
# Power_BHP               0
# Torque_Nm               0
# Mileage_kmpl            0
# Price_Ex_Showroom       0
# Owner_Type              0
# Insurance_Valid_Till    0
# Location                0
# Registration_State      0
# dtype: int64

# %% [markdown]
# # Filter cars manufactured after 2020

# %%
df[df['Year']> 2020]
# Out:
#           ID Model_Name      Variant  Year Fuel_Type Transmission  Engine_CC  \
# 10        11         i8   Sport Line  2024    Diesel       Manual       4395
# 16        17         M4     Standard  2022    Hybrid    Automatic       4395
# 22        23         M4     Standard  2023    Hybrid       Manual       4395
# 24        25         X3   Sport Line  2022    Hybrid    Automatic       1998
# 27        28         X7     Standard  2022    Diesel    Automatic       2993
# ...      ...        ...          ...   ...       ...          ...        ...
# 99986  99987         Z4     Standard  2021    Diesel       Manual       4395
# 99987  99988         X1     Standard  2023    Hybrid       Manual       2993
# 99991  99992         X1  Luxury Line  2023    Hybrid    Automatic       1496
# 99992  99993         Z4      M Sport  2021    Hybrid       Manual       1496
# 99996  99997         Z4   Sport Line  2021  Electric    Automatic       1496
#
# ...

# %% [markdown]
# # list unique car models and fuel types

# %%
df['Model_Name'].unique()
# Out:
# array(['X5', 'Z4', 'X7', 'X1', 'M3', '320d', 'X3', 'i8', 'M4', '520d'],
#       dtype=object)

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Electric', 'Hybrid', 'Petrol', 'Diesel'], dtype=object)

# %% [markdown]
# # Count how many cars per fual type

# %%
df['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Petrol      25125
# Diesel      25089
# Hybrid      24934
# Electric    24852
# Name: count, dtype: int64

# %% [markdown]
# # Sort datasets by Price_Ex_Showroom descending.

# %% [markdown]
# df.sort_values(by=['Price_Ex_Showroom'],ascending=False).head()

# %% [markdown]
# # Filter only Automatic tranmission BMWs

# %%
con=df['Transmission']=='Automatic Transmission'
df[con].head()
# Out:
# Empty DataFrame
# Columns: [ID, Model_Name, Variant, Year, Fuel_Type, Transmission, Engine_CC, Power_BHP, Torque_Nm, Mileage_kmpl, Price_Ex_Showroom, Owner_Type, Insurance_Valid_Till, Location, Registration_State]
# Index: []

# %% [markdown]
# # Replace missing values with mean

# %%
df['Mileage_kmpl'].fillna(df['Mileage_kmpl'].mean())
# Out:
# 0        20.48
# 1         8.12
# 2        16.24
# 3         9.80
# 4        23.47
#          ...
# 99995     9.83
# 99996    13.45
# 99997    14.44
# 99998    14.93
# 99999    13.97
# Name: Mileage_kmpl, Length: 100000, dtype: float64

# %% [markdown]
# # Drop rows where Engine_CC is null

# %%
df = df.dropna(subset=['Engine_CC'])

# %%
df
# Out:
#            ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric          Manual
# 1           2         X5  Luxury Line  2016  Electric       Automatic
# 2           3         Z4      M Sport  2012  Electric  Semi-Automatic
# 3           4         X7      M Sport  2013    Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric          Manual
# ...       ...        ...          ...   ...       ...             ...
# 99995   99996         Z4   Sport Line  2014    Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric       Automatic
# 99997   99998         M4     Standard  2012    Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric          Manual
# 99999  100000       520d  Luxury Line  2020  Electric  Semi-Automatic
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# # Group cars by Model_Name and calculate average price

# %%
df.groupby('Model_Name')['Price_Ex_Showroom'].mean()
# Out:
# Model_Name
# 320d    85.361262
# 520d    85.270653
# M3      85.090345
# M4      85.223891
# X1      84.612881
# X3      85.528270
# X5      85.401622
# X7      84.835493
# Z4      85.307179
# i8      85.086266
# Name: Price_Ex_Showroom, dtype: float64

# %% [markdown]
# # Create a new column Car_Age = 2025-Year

# %%
df['Car_Age'] = 2025 - df['Year']

# %%
df
# Out:
#            ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric          Manual
# 1           2         X5  Luxury Line  2016  Electric       Automatic
# 2           3         Z4      M Sport  2012  Electric  Semi-Automatic
# 3           4         X7      M Sport  2013    Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric          Manual
# ...       ...        ...          ...   ...       ...             ...
# 99995   99996         Z4   Sport Line  2014    Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric       Automatic
# 99997   99998         M4     Standard  2012    Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric          Manual
# 99999  100000       520d  Luxury Line  2020  Electric  Semi-Automatic
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# # Filter cars priced above rupees 60 lakh

# %%
df[df['Price_Ex_Showroom']>600000]
# Out:
# Empty DataFrame
# Columns: [ID, Model_Name, Variant, Year, Fuel_Type, Transmission, Engine_CC, Power_BHP, Torque_Nm, Mileage_kmpl, Price_Ex_Showroom, Owner_Type, Insurance_Valid_Till, Location, Registration_State, Car_Age]
# Index: []

# %% [markdown]
# # Find top 5 most common cities in the dataset

# %%
df['Location'].value_counts().head(5)
# Out:
# Location
# Ahmedabad    12668
# Chennai      12549
# Mumbai       12495
# Bangalore    12492
# Delhi        12478
# Name: count, dtype: int64

# %% [markdown]
# # Apply .loc[] to update fuel type of electric power

# %%
df.loc[df['Fuel_Type'] == 'Electric','Fuel_Type'] = 'Electric Power'

# %%
df
# Out:
#            ID Model_Name      Variant  Year       Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric Power          Manual
# 1           2         X5  Luxury Line  2016  Electric Power       Automatic
# 2           3         Z4      M Sport  2012  Electric Power  Semi-Automatic
# 3           4         X7      M Sport  2013          Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric Power          Manual
# ...       ...        ...          ...   ...             ...             ...
# 99995   99996         Z4   Sport Line  2014          Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric Power       Automatic
# 99997   99998         M4     Standard  2012          Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric Power          Manual
# 99999  100000       520d  Luxury Line  2020  Electric Power  Semi-Automatic
#
# ...

# %% [markdown]
# # Convert Price_Ex_Showroom from lakh to rupees value

# %%
df['Price_Ex_Showroom'] = df['Price_Ex_Showroom'] * 100000

# %%
df
# Out:
#            ID Model_Name      Variant  Year       Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric Power          Manual
# 1           2         X5  Luxury Line  2016  Electric Power       Automatic
# 2           3         Z4      M Sport  2012  Electric Power  Semi-Automatic
# 3           4         X7      M Sport  2013          Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric Power          Manual
# ...       ...        ...          ...   ...             ...             ...
# 99995   99996         Z4   Sport Line  2014          Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric Power       Automatic
# 99997   99998         M4     Standard  2012          Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric Power          Manual
# 99999  100000       520d  Luxury Line  2020  Electric Power  Semi-Automatic
#
# ...

# %% [markdown]
# # Find how many cars are older than 10 years

# %%
(df['Car_Age'] > 10).sum()
# Out:
# 33320

# %% [markdown]
# # Count of cars by Owner_Type and Transmission.

# %%
df.groupby(['Owner_Type','Transmission']).size()
# Out:
# Owner_Type      Transmission
# First           Automatic         8487
#                 Manual            8223
#                 Semi-Automatic    8332
# Fourth & Above  Automatic         8256
#                 Manual            8357
#                 Semi-Automatic    8378
# Second          Automatic         8549
#                 Manual            8175
#                 Semi-Automatic    8240
# Third           Automatic         8373
#                 Manual            8248
#                 Semi-Automatic    8382
# dtype: int64

# %% [markdown]
# # Find maximum BHP in diesel cars

# %%
df[df['Fuel_Type'] == 'Diesel']['Power_BHP'].max()
# Out:
# 624.98

# %% [markdown]
# # Count number of variants per model

# %%
df.groupby('Model_Name')['Variant'].nunique()
# Out:
# Model_Name
# 320d    5
# 520d    5
# M3      5
# M4      5
# X1      5
# X3      5
# X5      5
# X7      5
# Z4      5
# i8      5
# Name: Variant, dtype: int64

# %% [markdown]
# # Find car with max and min mileage

# %%
df.loc[df['Mileage_kmpl'].idxmax()]
# Out:
# ID                            7542
# Model_Name                      M3
# Variant                     xDrive
# Year                          2013
# Fuel_Type                   Hybrid
# Transmission                Manual
# Engine_CC                     1496
# Power_BHP                   474.04
# Torque_Nm                   739.46
# Mileage_kmpl                  25.0
# Price_Ex_Showroom       13167000.0
# Owner_Type                   First
# Insurance_Valid_Till          2023
# Location                   Kolkata
# Registration_State              TN
# Car_Age                         12
# Name: 7541, dtype: object

# %% [markdown]
# # Calculate median price per year

# %%
df.groupby('Year')['Price_Ex_Showroom'].median()
# Out:
# Year
# 2010    8599000.0
# 2011    8558500.0
# 2012    8485500.0
# 2013    8493000.0
# 2014    8484000.0
# 2015    8557000.0
# 2016    8546000.0
# 2017    8502000.0
# 2018    8509000.0
# 2019    8485000.0
# 2020    8515000.0
# 2021    8589000.0
# 2022    8526500.0
# 2023    8485000.0
# 2024    8524000.0
# Name: Price_Ex_Showroom, dtype: float64

# %% [markdown]
# # Create a columns Is_Luxury(if Price > rupees 70 lakh = yes).

# %%
df['Is_Luxury'] = df['Price_Ex_Showroom'].apply(lambda x:'Yes' if x > 7000000 else 'no')

# %%
df
# Out:
#            ID Model_Name      Variant  Year       Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric Power          Manual
# 1           2         X5  Luxury Line  2016  Electric Power       Automatic
# 2           3         Z4      M Sport  2012  Electric Power  Semi-Automatic
# 3           4         X7      M Sport  2013          Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric Power          Manual
# ...       ...        ...          ...   ...             ...             ...
# 99995   99996         Z4   Sport Line  2014          Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric Power       Automatic
# 99997   99998         M4     Standard  2012          Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric Power          Manual
# 99999  100000       520d  Luxury Line  2020  Electric Power  Semi-Automatic
#
# ...

# %% [markdown]
# # Remove duplicate rows if any

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#            ID Model_Name      Variant  Year       Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric Power          Manual
# 1           2         X5  Luxury Line  2016  Electric Power       Automatic
# 2           3         Z4      M Sport  2012  Electric Power  Semi-Automatic
# 3           4         X7      M Sport  2013          Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric Power          Manual
# ...       ...        ...          ...   ...             ...             ...
# 99995   99996         Z4   Sport Line  2014          Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric Power       Automatic
# 99997   99998         M4     Standard  2012          Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric Power          Manual
# 99999  100000       520d  Luxury Line  2020  Electric Power  Semi-Automatic
#
# ...

# %% [markdown]
# # Applay filter: Diesel + Automatic + Above 200 BHP

# %%
df[(df['Fuel_Type'] == 'Diesel') & (df['Transmission'] == 'Automatic') & (df['Power_BHP'] > 200)]
# Out:
#           ID Model_Name      Variant  Year Fuel_Type Transmission  Engine_CC  \
# 45        46         X3       xDrive  2016    Diesel    Automatic       1998
# 77        78         Z4  Luxury Line  2019    Diesel    Automatic       1998
# 118      119       520d      M Sport  2011    Diesel    Automatic       1998
# 127      128       520d      M Sport  2016    Diesel    Automatic       1496
# 138      139         Z4  Luxury Line  2024    Diesel    Automatic       4395
# ...      ...        ...          ...   ...       ...          ...        ...
# 99903  99904         Z4       xDrive  2012    Diesel    Automatic       4395
# 99919  99920       320d   Sport Line  2021    Diesel    Automatic       4395
# 99926  99927       520d     Standard  2021    Diesel    Automatic       1998
# 99934  99935         M3  Luxury Line  2018    Diesel    Automatic       4395
# 99947  99948         X7   Sport Line  2012    Diesel    Automatic       1998
#
# ...
